# %% [markdown]
# <a href="https://colab.research.google.com/github/harkie24/genlink/blob/main/notebooks/03_Data_Merging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
genes = pd.read_csv("/content/ensembl_genes.csv")
diseases = pd.read_csv("/content/rare_gene_disease_dataset.csv")

# %% [markdown]
# # **Merging both Datasets**
#
# The 'gene_symbol column is the only common column between the two datasets.
#
# *   *Rare Gene Diseases* dataset gives disease-gene relationship
# *   *Ensemble Genes* dataset gives us gene-gene information relationship
#
# So it can be useful to merge these datasets.

# %%
merged = pd.merge(diseases, genes, left_on = 'gene_symbol', right_on = 'gene_symbol', how = 'inner')
merged.head()
# Out:
#                                disease gene_symbol  \
# 0  Paroxysmal nocturnal hemoglobinuria        PIGA
# 1                  Birk-Barel syndrome       KCNK9
# 2     Dentinogenesis imperfecta type 2        DSPP
# 3     Dentinogenesis imperfecta type 3        DSPP
# 4       Hereditary sick sinus syndrome        HCN4
#
#                                       gene_full_name  ensembl_gene_id  \
# 0  phosphatidylinositol glycan anchor biosynthesi...  ENSG00000165195
# 1  potassium two pore domain channel subfamily K ...  ENSG00000169427
# 2                         dentin sialophosphoprotein  ENSG00000152591
# 3                         dentin sialophosphoprotein  ENSG00000152591
# 4  hyperpolarization activated cyclic nucleotide ...  ENSG00000138622
#
#   chromosome      start        end  strand         biotype  \
# 0          X   15319452   15335554      -1  protein_coding
# 1          8  139600838  139704109      -1  protein_coding
# 2          4   87608529   87616873       1  protein_coding
# 3          4   87608529   87616873       1  protein_coding
# 4         15   73319859   73368958      -1  protein_coding
#
#                                          description
# 0  phosphatidylinositol glycan anchor biosynthesi...
# 1  potassium two pore domain channel subfamily K ...
# 2  dentin sialophosphoprotein [Source:HGNC Symbol...
# 3  dentin sialophosphoprotein [Source:HGNC Symbol...
# 4  hyperpolarization activated cyclic nucleotide ...

# %% [markdown]
# **how = "inner"** keeps only the matches
#
# **how = "left"** keeps everything from the disease dataset
#
# **how = "right"** keeps everything from the gene dataset
#
# **how = "outer"** keeps everything from both datasets
